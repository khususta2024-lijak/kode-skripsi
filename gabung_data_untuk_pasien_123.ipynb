# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/TA

#!pip install mne
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import mne #library untuk pemrosesan sinyal elektroensefalografi (EEG)
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/TA

# %%
T_1 = pd.read_csv("/content/drive/MyDrive/TA/FFT BLACKMAN DONE/chb01_03.csv")
T_2 = pd.read_csv("/content/drive/MyDrive/TA/FFT BLACKMAN DONE/chb01_04.csv")
T_3 = pd.read_csv("/content/drive/MyDrive/TA/FFT BLACKMAN DONE/chb01_15.csv")
T_4 = pd.read_csv("/content/drive/MyDrive/TA/FFT BLACKMAN DONE/chb01_16.csv")
T_5 = pd.read_csv("/content/drive/MyDrive/TA/FFT BLACKMAN DONE/chb01_18.csv")
T_6 = pd.read_csv("/content/drive/MyDrive/TA/FFT BLACKMAN DONE/chb01_21.csv")
T_7 = pd.read_csv("/content/drive/MyDrive/TA/FFT BLACKMAN DONE/chb01_26.csv")

T_data = pd.concat([T_1, T_2, T_3, T_4, T_5, T_6, T_7], ignore_index=True)

# Simpan data yang digabung
T_data.to_csv("/content/drive/MyDrive/TA/PASIEN CHB01 BLACKMAN.csv", index=False)

# %%
T_8 = pd.read_csv("/content/drive/MyDrive/TA/FFT BLACKMAN DONE/chb02_16.csv")
T_9 = pd.read_csv("/content/drive/MyDrive/TA/FFT BLACKMAN DONE/chb02_16+.csv")
T_10 = pd.read_csv("/content/drive/MyDrive/TA/FFT BLACKMAN DONE/chb02_19.csv")

T_data = pd.concat([T_8, T_9, T_10], ignore_index=True)

# Simpan data yang digabung
T_data.to_csv("/content/drive/MyDrive/TA/PASIEN CHB02 BLACKMAN.csv", index=False)

# %%
T_11 = pd.read_csv("/content/drive/MyDrive/TA/FFT BLACKMAN DONE/chb03_01.csv")
T_12 = pd.read_csv("/content/drive/MyDrive/TA/FFT BLACKMAN DONE/chb03_02.csv")
T_13 = pd.read_csv("/content/drive/MyDrive/TA/FFT BLACKMAN DONE/chb03_03.csv")
T_14 = pd.read_csv("/content/drive/MyDrive/TA/FFT BLACKMAN DONE/chb03_04.csv")
T_15 = pd.read_csv("/content/drive/MyDrive/TA/FFT BLACKMAN DONE/chb03_34.csv")
T_16 = pd.read_csv("/content/drive/MyDrive/TA/FFT BLACKMAN DONE/chb03_35.csv")
T_17 = pd.read_csv("/content/drive/MyDrive/TA/FFT BLACKMAN DONE/chb03_36.csv")

T_data = pd.concat([T_11, T_12, T_13, T_14, T_15, T_16, T_17], ignore_index=True)

# Simpan data yang digabung
T_data.to_csv("/content/drive/MyDrive/TA/PASIEN CHB03 BLACKMAN.csv", index=False)

# %% [markdown]
# # RECTANGULAR

# %%
T_1 = pd.read_csv("/content/drive/MyDrive/TA/FFT RECTANGULAR DONE/chb01_03.csv")
T_2 = pd.read_csv("/content/drive/MyDrive/TA/FFT RECTANGULAR DONE/chb01_04.csv")
T_3 = pd.read_csv("/content/drive/MyDrive/TA/FFT RECTANGULAR DONE/chb01_15.csv")
T_4 = pd.read_csv("/content/drive/MyDrive/TA/FFT RECTANGULAR DONE/chb01_16.csv")
T_5 = pd.read_csv("/content/drive/MyDrive/TA/FFT RECTANGULAR DONE/chb01_18.csv")
T_6 = pd.read_csv("/content/drive/MyDrive/TA/FFT RECTANGULAR DONE/chb01_21.csv")
T_7 = pd.read_csv("/content/drive/MyDrive/TA/FFT RECTANGULAR DONE/chb01_26.csv")

T_data = pd.concat([T_1, T_2, T_3, T_4, T_5, T_6, T_7], ignore_index=True)

# Simpan data yang digabung
T_data.to_csv("/content/drive/MyDrive/TA/PASIEN CHB01 RECTANGULAR.csv", index=False)

# %%
T_8 = pd.read_csv("/content/drive/MyDrive/TA/FFT RECTANGULAR DONE/chb02_16.csv")
T_9 = pd.read_csv("/content/drive/MyDrive/TA/FFT RECTANGULAR DONE/chb02_16+.csv")
T_10 = pd.read_csv("/content/drive/MyDrive/TA/FFT RECTANGULAR DONE/chb02_19.csv")

T_data = pd.concat([T_8, T_9, T_10], ignore_index=True)

# Simpan data yang digabung
T_data.to_csv("/content/drive/MyDrive/TA/PASIEN CHB02 RECTANGULAR.csv", index=False)

# %%
T_11 = pd.read_csv("/content/drive/MyDrive/TA/FFT RECTANGULAR DONE/chb03_01.csv")
T_12 = pd.read_csv("/content/drive/MyDrive/TA/FFT RECTANGULAR DONE/chb03_02.csv")
T_13 = pd.read_csv("/content/drive/MyDrive/TA/FFT RECTANGULAR DONE/chb03_03.csv")
T_14 = pd.read_csv("/content/drive/MyDrive/TA/FFT RECTANGULAR DONE/chb03_04.csv")
T_15 = pd.read_csv("/content/drive/MyDrive/TA/FFT RECTANGULAR DONE/chb03_34.csv")
T_16 = pd.read_csv("/content/drive/MyDrive/TA/FFT RECTANGULAR DONE/chb03_35.csv")
T_17 = pd.read_csv("/content/drive/MyDrive/TA/FFT RECTANGULAR DONE/chb03_36.csv")

T_data = pd.concat([T_11, T_12, T_13, T_14, T_15, T_16, T_17], ignore_index=True)

# Simpan data yang digabung
T_data.to_csv("/content/drive/MyDrive/TA/PASIEN CHB03 RECTANGULAR.csv", index=False)

# %% [markdown]
# # HAMMING

# %%
T_1 = pd.read_csv("/content/drive/MyDrive/TA/FFT HAMMING DONE/chb01_03.csv")
T_2 = pd.read_csv("/content/drive/MyDrive/TA/FFT HAMMING DONE/chb01_04.csv")
T_3 = pd.read_csv("/content/drive/MyDrive/TA/FFT HAMMING DONE/chb01_15.csv")
T_4 = pd.read_csv("/content/drive/MyDrive/TA/FFT HAMMING DONE/chb01_16.csv")
T_5 = pd.read_csv("/content/drive/MyDrive/TA/FFT HAMMING DONE/chb01_18.csv")
T_6 = pd.read_csv("/content/drive/MyDrive/TA/FFT HAMMING DONE/chb01_21.csv")
T_7 = pd.read_csv("/content/drive/MyDrive/TA/FFT HAMMING DONE/chb01_26.csv")

T_data = pd.concat([T_1, T_2, T_3, T_4, T_5, T_6, T_7], ignore_index=True)

# Simpan data yang digabung
T_data.to_csv("/content/drive/MyDrive/TA/PASIEN CHB01 HAMMING.csv", index=False)

# %%
T_8 = pd.read_csv("/content/drive/MyDrive/TA/FFT HAMMING DONE/chb02_16.csv")
T_9 = pd.read_csv("/content/drive/MyDrive/TA/FFT HAMMING DONE/chb02_16+.csv")
T_10 = pd.read_csv("/content/drive/MyDrive/TA/FFT HAMMING DONE/chb02_19.csv")

T_data = pd.concat([T_8, T_9, T_10], ignore_index=True)

# Simpan data yang digabung
T_data.to_csv("/content/drive/MyDrive/TA/PASIEN CHB02 HAMMING.csv", index=False)

# %%
T_11 = pd.read_csv("/content/drive/MyDrive/TA/FFT HAMMING DONE/chb03_01.csv")
T_12 = pd.read_csv("/content/drive/MyDrive/TA/FFT HAMMING DONE/chb03_02.csv")
T_13 = pd.read_csv("/content/drive/MyDrive/TA/FFT HAMMING DONE/chb03_03.csv")
T_14 = pd.read_csv("/content/drive/MyDrive/TA/FFT HAMMING DONE/chb03_04.csv")
T_15 = pd.read_csv("/content/drive/MyDrive/TA/FFT HAMMING DONE/chb03_34.csv")
T_16 = pd.read_csv("/content/drive/MyDrive/TA/FFT HAMMING DONE/chb03_35.csv")
T_17 = pd.read_csv("/content/drive/MyDrive/TA/FFT HAMMING DONE/chb03_36.csv")

T_data = pd.concat([T_11, T_12, T_13, T_14, T_15, T_16, T_17], ignore_index=True)

# Simpan data yang digabung
T_data.to_csv("/content/drive/MyDrive/TA/PASIEN CHB03 HAMMING.csv", index=False)

# %% [markdown]
# # HANNING

# %%
T_1 = pd.read_csv("/content/drive/MyDrive/TA/FFT HANNING DONE/chb01_03.csv")
T_2 = pd.read_csv("/content/drive/MyDrive/TA/FFT HANNING DONE/chb01_04.csv")
T_3 = pd.read_csv("/content/drive/MyDrive/TA/FFT HANNING DONE/chb01_15.csv")
T_4 = pd.read_csv("/content/drive/MyDrive/TA/FFT HANNING DONE/chb01_16.csv")
T_5 = pd.read_csv("/content/drive/MyDrive/TA/FFT HANNING DONE/chb01_18.csv")
T_6 = pd.read_csv("/content/drive/MyDrive/TA/FFT HANNING DONE/chb01_21.csv")
T_7 = pd.read_csv("/content/drive/MyDrive/TA/FFT HANNING DONE/chb01_26.csv")

T_data = pd.concat([T_1, T_2, T_3, T_4, T_5, T_6, T_7], ignore_index=True)

# Simpan data yang digabung
T_data.to_csv("/content/drive/MyDrive/TA/PASIEN CHB01 HANNING.csv", index=False)

# %%
T_8 = pd.read_csv("/content/drive/MyDrive/TA/FFT HANNING DONE/chb02_16.csv")
T_9 = pd.read_csv("/content/drive/MyDrive/TA/FFT HANNING DONE/chb02_16+.csv")
T_10 = pd.read_csv("/content/drive/MyDrive/TA/FFT HANNING DONE/chb02_19.csv")

T_data = pd.concat([T_8, T_9, T_10], ignore_index=True)

# Simpan data yang digabung
T_data.to_csv("/content/drive/MyDrive/TA/PASIEN CHB02 HANNING.csv", index=False)

# %%
T_11 = pd.read_csv("/content/drive/MyDrive/TA/FFT HANNING DONE/chb03_01.csv")
T_12 = pd.read_csv("/content/drive/MyDrive/TA/FFT HANNING DONE/chb03_02.csv")
T_13 = pd.read_csv("/content/drive/MyDrive/TA/FFT HANNING DONE/chb03_03.csv")
T_14 = pd.read_csv("/content/drive/MyDrive/TA/FFT HANNING DONE/chb03_04.csv")
T_15 = pd.read_csv("/content/drive/MyDrive/TA/FFT HANNING DONE/chb03_34.csv")
T_16 = pd.read_csv("/content/drive/MyDrive/TA/FFT HANNING DONE/chb03_35.csv")
T_17 = pd.read_csv("/content/drive/MyDrive/TA/FFT HANNING DONE/chb03_36.csv")

T_data = pd.concat([T_11, T_12, T_13, T_14, T_15, T_16, T_17], ignore_index=True)

# Simpan data yang digabung
T_data.to_csv("/content/drive/MyDrive/TA/PASIEN CHB03 HANNING.csv", index=False)
