X = mydata.drop(['frekuensi', 'seizure'], axis=1)
y = mydata['seizure']

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
y = encoder.fit_transform(y)  # "kejang" -> 1, "tidak kejang" -> 0

# %%
# split dataset train dan test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (2245632, 23)

# %%
X_test.shape
# Out:
# (561408, 23)

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Inisialisasi model/buat model dasar
rf = RandomForestClassifier(random_state=42)

# Ruang hyperparameter untuk Grid Search
param_grid = {
    'max_depth': [5, 10, 20],
}

# %%
scoring = {
    'accuracy': 'accuracy',
    'precision': 'precision',
    'recall': 'recall',
    'f1': 'f1',
    'mcc': 'matthews_corrcoef',
    'balanced_acc': 'balanced_accuracy',
    'logloss': 'neg_log_loss',
    'roc_auc': 'roc_auc'
}

# %%
# GridSearchCV
grid_search = GridSearchCV(
    rf,
    param_grid=param_grid,
    scoring=scoring,
    cv=skf,
    refit='accuracy',   # pilih satu metrik untuk refit
    n_jobs=-1,
    return_train_score=True
)

# %%
# Fit
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [5, 10, 20]}, refit='accuracy',
#              return_train_score=True,
#              scoring={'accuracy': 'accuracy',
#                       'balanced_acc': 'balanced_accuracy', 'f1': 'f1',
#                       'logloss': 'neg_log_loss', 'mcc': 'matthews_corrcoef',
#                       'precision': 'precision', 'recall': 'recall',
#                       'roc_auc': 'roc_auc'})

# %%
results = pd.DataFrame(grid_search.cv_results_)
resultss = results.T
print(resultss)
# Out:
#                                 0            1            2
# mean_fit_time         1316.211134  2489.710812  4115.139074
# std_fit_time            10.798205    23.030947   340.725674
# mean_score_time          7.696623    13.389615    30.552264
# std_score_time           0.487481      0.39237     3.596147
# param_max_depth                 5           10           20
# ...                           ...          ...          ...
# split2_train_roc_auc     0.712111     0.890255     0.974053
# split3_train_roc_auc     0.710113     0.887067     0.972276
# split4_train_roc_auc     0.710521     0.889999     0.973949
# mean_train_roc_auc       0.710153     0.888754     0.973464
# std_train_roc_auc        0.001149     0.001273     0.000645
#
# [126 rows x 3 columns]

# %%
resultss.to_csv('results banyak rectangular.csv')

# %%
results = pd.DataFrame(grid_search.cv_results_)[
    ['params', 'mean_test_accuracy', 'mean_test_precision',
     'mean_test_recall', 'mean_test_f1', 'mean_test_mcc', 'mean_test_balanced_acc',
     'mean_test_logloss', 'mean_test_roc_auc']
]
results
# Out:
#               params  mean_test_accuracy  mean_test_precision  \
# 0   {'max_depth': 5}            0.663299             0.624399
# 1  {'max_depth': 10}            0.766282             0.697789
# 2  {'max_depth': 20}            0.857068             0.807542
#
#    mean_test_recall  mean_test_f1  mean_test_mcc  mean_test_balanced_acc  \
# 0          0.819654      0.708826       0.343843                0.663299
# 1          0.939453      0.800783       0.567703                0.766282
# 2          0.937594      0.867720       0.723585                0.857068
#
#    mean_test_logloss  mean_test_roc_auc
# 0          -0.634502           0.709705
# 1          -0.514736           0.886360
# 2          -0.309322           0.951861

# %%
# Hasil
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'max_depth': 20}
# Best Score: 0.8570682991196372

# %%
#pediksi data test
y_test_pred = grid_search.predict(X_test)

# Akurasi data uji
print("\n📋 Classification Report - Data Uji:")
print(classification_report(y_test, y_test_pred, digits=4))

# ====================
# Confusion Matrix - Data Uji
# ====================

cm_test = confusion_matrix(y_test, y_test_pred)

# Visualisasi tanpa garis hitam
plt.figure(figsize=(5, 5))
sns.heatmap(cm_test, annot=True, fmt='d', cmap='Oranges',
            xticklabels=['Tidak Kejang', 'Kejang'],
            yticklabels=['Tidak Kejang', 'Kejang'],
            cbar=False)  # opsional: sembunyikan colorbar

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Data Uji")
plt.tight_layout()
plt.show()
# Out:
# 📋 Classification Report - Data Uji:
#               precision    recall  f1-score   support
#
#            0     0.9278    0.7748    0.8444    280704
#            1     0.8067    0.9397    0.8681    280704
#
#     accuracy                         0.8573    561408
#    macro avg     0.8673    0.8573    0.8563    561408
# weighted avg     0.8673    0.8573    0.8563    561408

# %%
# Prediksi data latih
y_train_pred = grid_search.predict(X_train) #menghasilakn label prediksi dari fitur

print("📋 Classification Report - Data Latih:")
print(classification_report(y_train, y_train_pred, digits=4)) # mengevaluasi seberapa baik prediksi dibanding label asli


# ====================
# Confusion Matrix - Data Latih
# ====================

cm_train = confusion_matrix(y_train, y_train_pred)

# Visualisasi tanpa garis hitam
plt.figure(figsize=(5, 5))
sns.heatmap(cm_train, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Tidak Kejang', 'Kejang'],
            yticklabels=['Tidak Kejang', 'Kejang'],
            cbar=False)  # opsional: sembunyikan colorbar

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Data Latih")
plt.tight_layout()
plt.show()
# Out:
# 📋 Classification Report - Data Latih:
#               precision    recall  f1-score   support
#
#            0     0.9721    0.8005    0.8780   1122816
#            1     0.8305    0.9771    0.8978   1122816
#
#     accuracy                         0.8888   2245632
#    macro avg     0.9013    0.8888    0.8879   2245632
# weighted avg     0.9013    0.8888    0.8879   2245632

# %%
# ====================
# 5. Feature Importance
# ====================
best_rf = grid_search.best_estimator_   # model terbaik hasil GridSearchCV
importances = best_rf.feature_importances_
feature_names = X.columns

# Buat DataFrame
feat_imp = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

print("\n📊 Feature Importance:")
print(feat_imp)

# Visualisasi Feature Importance
plt.figure(figsize=(8, 6))
sns.barplot(data=feat_imp, x='Importance', y='Feature', palette='viridis')
plt.title("Feature Importance (Random Forest)")
plt.tight_layout()
plt.show()
# Out:
# 📊 Feature Importance:
#      Feature  Importance
# 16     FZ-CZ    0.056034
# 17     CZ-PZ    0.055827
# 3      P7-O1    0.053868
# 8     FP2-F4    0.052122
# 10     C4-P4    0.051046
# 7      P3-O1    0.050932
# 6      C3-P3    0.047653
# 20  FT9-FT10    0.046565
# 4     FP1-F3    0.044529
# 0     FP1-F7    0.044433
# 13     F8-T8    0.043593
# 9      F4-C4    0.043448
# 11     P4-O2    0.042824
# 15     P8-O2    0.042790
# 12    FP2-F8    0.042013
# 5      F3-C3    0.040209
# 1      F7-T7    0.038628
# 14   T8-P8-0    0.036348
# 19    T7-FT9    0.035677
# 22   T8-P8-1    0.034348
# 2      T7-P7    0.034280
# 21   FT10-T8    0.031716
# 18     P7-T7    0.031118
# /tmp/ipython-input-2869360155.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=feat_imp, x='Importance', y='Feature', palette='viridis')

# %% [markdown]
# # sidang

# %%
import numpy as np
cm = np.array([
    [4, 1],
    [2, 3]
])
cm
# Out:
# array([[4, 1],
#        [2, 3]])

# %%
tp = cm[0][0]
tn = cm[1][1]
fp = cm[1][0]
fn = cm[0][1]

# %%
presisi = (tp) / (tp+fp)
presisi
# Out:
# np.float64(0.6666666666666666)

# %%
recall =(tp) / (tp+fn)
recall
# Out:
# np.float64(0.8)

# %%
akurasi = (tp+tn) /(tp+tn+fp+fn)
akurasi
# Out:
# np.float64(0.7)

# %%
a = np.array([
    [2, 4, 5],
    [-1, 4, 1],
    [3, -2, -3]
])
a
# Out:
# array([[ 2,  4,  5],
#        [-1,  4,  1],
#        [ 3, -2, -3]])

# %%
# filter untuk cari nilai kurang dari 5, kemudian jumlahkan
filter = np.where(a < 5)
filter
# Out:
# (array([0, 0, 1, 1, 1, 2, 2, 2]), array([0, 1, 0, 1, 2, 0, 1, 2]))

# %%
filter = a < 5
filter
# Out:
# array([[ True,  True, False],
#        [ True,  True,  True],
#        [ True,  True,  True]])

# %%
np.sum(filter)
# Out:
# np.int64(8)

# %%
np.sum(a)
# Out:
# np.int64(13)

# %%
np.sum(filter)
# Out:
# np.int64(16)

# %%
arr = a.to_list()
arr
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3397204906.py in <cell line: 0>()
# ----> 1 arr = a.to_list()
#       2 arr
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_list'

# %%
import pandas as pd
df = pd.DataFrame(a)
df
# Out:
#    0  1  2
# 0  2  4  5
# 1 -1  4  1
# 2  3 -2 -3

# %%
filter = df[(df) < 5]
filter
# Out:
#    0  1    2
# 0  2  4  NaN
# 1 -1  4  1.0
# 2  3 -2 -3.0

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-943149741.py in <cell line: 0>()
# ----> 1 arr = filter.values()
#       2 arr
#
# AttributeError: 'tuple' object has no attribute 'values'

# %%
# filter untuk cari nilai kurang dari 5, kemudian jumlahkan
filter = np.where(a < 5, 'true', 'false')
filter
# Out:
# array([['true', 'true', 'false'],
#        ['true', 'true', 'true'],
#        ['true', 'true', 'true']], dtype='<U5')

# %% [markdown]
# # HANNING (kode setelah bimbingan)

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/TA

import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
mydata = pd.read_csv("/content/drive/MyDrive/TA/fft_chb16_16.csv")
mydata
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/TA
#         FP1-F7     F7-T7     T7-P7     P7-O1    FP1-F3     F3-C3     C3-P3  \
# 0     0.000759  0.000068  0.000240  0.000172  0.001114  0.000437  0.000072
# 1     0.000780  0.000078  0.000262  0.000178  0.001139  0.000473  0.000152
# 2     0.000862  0.000117  0.000322  0.000197  0.001220  0.000581  0.000295
# 3     0.001040  0.000214  0.000423  0.000234  0.001337  0.000771  0.000494
# 4     0.001808  0.000431  0.000981  0.000622  0.002003  0.001396  0.001006
# ...        ...       ...       ...       ...       ...       ...       ...
# 1531  0.000070  0.000030  0.000027  0.000005  0.000059  0.000005  0.000006
# 1532  0.000052  0.000020  0.000029  0.000018  0.000020  0.000053  0.000019
# 1533  0.000070  0.000030  0.000027  0.000005  0.000059  0.000005  0.000006
# 1534  0.000052  0.000020  0.000029  0.000018  0.000020  0.000053  0.000019
# 1535  0.000070  0.000030  0.000027  0.000005  0.000059  0.000005  0.000006
#
#          P3-O1    FP2-F4     F4-C4  ...     P8-O2     FZ-CZ     CZ-PZ  \
# 0     0.000371  0.001558  0.000496  ...  0.001002  0.001755  0.000117
# 1     0.000375  0.001592  0.000505  ...  0.001009  0.001789  0.000172
# 2     0.000390  0.001714  0.000535  ...  0.001031  0.001899  0.000294
# 3     0.000420  0.001961  0.000588  ...  0.001070  0.002129  0.000478
# 4     0.000511  0.002896  0.000881  ...  0.000959  0.003096  0.001038
# ...        ...       ...       ...  ...       ...       ...       ...
# 1531  0.000019  0.000007  0.000026  ...  0.000061  0.000009  0.000005
# 1532  0.000037  0.000025  0.000012  ...  0.000048  0.000055  0.000006
# 1533  0.000019  0.000007  0.000026  ...  0.000061  0.000009  0.000005
# 1534  0.000036  0.000025  0.000012  ...  0.000048  0.000055  0.000006
# 1535  0.000019  0.000007  0.000026  ...  0.000061  0.000009  0.000005
#
#          P7-T7    T7-FT9  FT9-FT10   FT10-T8   T8-P8-1       seizure  \
# 0     0.000239  0.000267  0.000331  0.002075  0.000271        kejang
# 1     0.000260  0.000267  0.000447  0.002100  0.000291        kejang
# 2     0.000321  0.000272  0.000731  0.002181  0.000352        kejang
# 3     0.000422  0.000309  0.001192  0.002337  0.000464        kejang
# 4     0.000981  0.000420  0.002118  0.002624  0.001064        kejang
# ...        ...       ...       ...       ...       ...           ...
# 1531  0.000027  0.000039  0.000073  0.000008  0.000015  tidak kejang
# 1532  0.000029  0.000004  0.000021  0.000007  0.000058  tidak kejang
# 1533  0.000027  0.000039  0.000073  0.000008  0.000015  tidak kejang
# 1534  0.000029  0.000004  0.000021  0.000007  0.000058  tidak kejang
# 1535  0.000027  0.000039  0.000073  0.000008  0.000015  tidak kejang
#
#        frekuensi
# 0       0.000000
# 1       0.166667
# 2       0.333333
# 3       0.500000
# 4       0.666667
# ...          ...
# 1531  127.166667
# 1532  127.333333
# 1533  127.500000
# 1534  127.666667
# 1535  127.833333
#
# [1536 rows x 25 columns]

# %%
# Pisahkan fitur (X) dan label (y)
X = mydata.drop(['frekuensi', 'seizure'], axis=1)
y = mydata['seizure']

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
y = encoder.fit_transform(y)  # "kejang" -> 1, "tidak kejang" -> 0

# %%
# split dataset train dan test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (1228, 23)

# %%
X_test.shape
# Out:
# (308, 23)

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Inisialisasi model/buat model dasar
rf = RandomForestClassifier(random_state=42)

# Ruang hyperparameter untuk Grid Search
param_grid = {
    'max_depth': [5, 10, 20],
}

# %%
scoring = {
    'accuracy': 'accuracy',
    'precision': 'precision',
    'recall': 'recall',
    'f1': 'f1',
    'mcc': 'matthews_corrcoef',
    'balanced_acc': 'balanced_accuracy',
    'logloss': 'neg_log_loss',
    'roc_auc': 'roc_auc'
}

# %%
# GridSearchCV
grid_search = GridSearchCV(
    rf,
    param_grid=param_grid,
    scoring=scoring,
    cv=skf,
    refit='accuracy',   # pilih satu metrik untuk refit
    n_jobs=-1,
    return_train_score=True
)

# %%
# Fit
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [5, 10, 20]}, refit='accuracy',
#              return_train_score=True,
#              scoring={'accuracy': 'accuracy',
#                       'balanced_acc': 'balanced_accuracy', 'f1': 'f1',
#                       'logloss': 'neg_log_loss', 'mcc': 'matthews_corrcoef',
#                       'precision': 'precision', 'recall': 'recall',
#                       'roc_auc': 'roc_auc'})

# %%
results = pd.DataFrame(grid_search.cv_results_)
resultss = results.T
print(resultss)
# Out:
#                              0         1         2
# mean_fit_time          0.49442  0.613076  0.582775
# std_fit_time           0.01515  0.011847  0.031943
# mean_score_time        0.05839   0.05635  0.054429
# std_score_time        0.012582  0.009234  0.004226
# param_max_depth              5        10        20
# ...                        ...       ...       ...
# split2_train_roc_auc  0.989779  0.999925       1.0
# split3_train_roc_auc  0.990491  0.999938       1.0
# split4_train_roc_auc   0.99105  0.999963       1.0
# mean_train_roc_auc    0.989762  0.999894       1.0
# std_train_roc_auc     0.000923  0.000064       0.0
#
# [126 rows x 3 columns]

# %%
results = pd.DataFrame(grid_search.cv_results_)[
    ['params', 'mean_test_accuracy', 'mean_test_precision',
     'mean_test_recall', 'mean_test_f1', 'mean_test_mcc', 'mean_test_balanced_acc',
     'mean_test_logloss', 'mean_test_roc_auc']
]
results
# Out:
#               params  mean_test_accuracy  mean_test_precision  \
# 0   {'max_depth': 5}            0.912029             0.912578
# 1  {'max_depth': 10}            0.929942             0.935722
# 2  {'max_depth': 20}            0.929939             0.936724
#
#    mean_test_recall  mean_test_f1  mean_test_mcc  mean_test_balanced_acc  \
# 0          0.912009      0.912052       0.824488                0.911995
# 1          0.925030      0.929787       0.860937                0.929895
# 2          0.923404      0.929629       0.860664                0.929895
#
#    mean_test_logloss  mean_test_roc_auc
# 0          -0.202471           0.978700
# 1          -0.166399           0.984182
# 2          -0.164151           0.984515

# %%
# Hasil
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'max_depth': 10}
# Best Score: 0.9299419279907084

# %%
#pediksi data test
y_test_pred = grid_search.predict(X_test)

# Akurasi data uji
print("\n📋 Classification Report - Data Uji:")
print(classification_report(y_test, y_test_pred, digits=4))

# ====================
# Confusion Matrix - Data Uji
# ====================

cm_test = confusion_matrix(y_test, y_test_pred)

# Visualisasi tanpa garis hitam
plt.figure(figsize=(5, 5))
sns.heatmap(cm_test, annot=True, fmt='d', cmap='Oranges',
            xticklabels=['Tidak Kejang', 'Kejang'],
            yticklabels=['Tidak Kejang', 'Kejang'],
            cbar=False)  # opsional: sembunyikan colorbar

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Data Uji")
plt.tight_layout()
plt.show()
# Out:
# 📋 Classification Report - Data Uji:
#               precision    recall  f1-score   support
#
#            0     0.9367    0.9610    0.9487       154
#            1     0.9600    0.9351    0.9474       154
#
#     accuracy                         0.9481       308
#    macro avg     0.9484    0.9481    0.9480       308
# weighted avg     0.9484    0.9481    0.9480       308

# %%
# Prediksi data latih
y_train_pred = grid_search.predict(X_train) #menghasilakn label prediksi dari fitur

print("📋 Classification Report - Data Latih:")
print(classification_report(y_train, y_train_pred, digits=4)) # mengevaluasi seberapa baik prediksi dibanding label asli


# ====================
# Confusion Matrix - Data Latih
# ====================

cm_train = confusion_matrix(y_train, y_train_pred)

# Visualisasi tanpa garis hitam
plt.figure(figsize=(5, 5))
sns.heatmap(cm_train, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Tidak Kejang', 'Kejang'],
            yticklabels=['Tidak Kejang', 'Kejang'],
            cbar=False)  # opsional: sembunyikan colorbar

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Data Latih")
plt.tight_layout()
plt.show()
# Out:
# 📋 Classification Report - Data Latih:
#               precision    recall  f1-score   support
#
#            0     0.9951    0.9902    0.9927       614
#            1     0.9903    0.9951    0.9927       614
#
#     accuracy                         0.9927      1228
#    macro avg     0.9927    0.9927    0.9927      1228
# weighted avg     0.9927    0.9927    0.9927      1228

# %%
# ====================
# 5. Feature Importance
# ====================
best_rf = grid_search.best_estimator_   # model terbaik hasil GridSearchCV
importances = best_rf.feature_importances_
feature_names = X.columns

# Buat DataFrame
feat_imp = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

print("\n📊 Feature Importance:")
print(feat_imp)

# Visualisasi Feature Importance
plt.figure(figsize=(8, 6))
sns.barplot(data=feat_imp, x='Importance', y='Feature', palette='viridis')
plt.title("Feature Importance (Random Forest)")
plt.tight_layout()
plt.show()
# Out:
# 📊 Feature Importance:
#      Feature  Importance
# 13     F8-T8    0.148758
# 1      F7-T7    0.089364
# 19    T7-FT9    0.072993
# 17     CZ-PZ    0.061776
# 18     P7-T7    0.057325
# 22   T8-P8-1    0.053215
# 21   FT10-T8    0.050545
# 16     FZ-CZ    0.049756
# 5      F3-C3    0.048916
# 6      C3-P3    0.046247
# 2      T7-P7    0.044790
# 14   T8-P8-0    0.042452
# 11     P4-O2    0.032544
# 4     FP1-F3    0.030201
# 3      P7-O1    0.025926
# 0     FP1-F7    0.022343
# 15     P8-O2    0.022315
# 12    FP2-F8    0.020744
# 20  FT9-FT10    0.019944
# 9      F4-C4    0.018109
# 8     FP2-F4    0.016151
# 10     C4-P4    0.013274
# 7      P3-O1    0.012313
# /tmp/ipython-input-2869360155.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=feat_imp, x='Importance', y='Feature', palette='viridis')

# %%
# ====================
# Visualisasi Feature Importance
# ====================
plt.figure(figsize=(8, 6))
sns.barplot(
    data=feat_imp,
    x='Importance',
    y='Feature',
    palette='viridis'
)
plt.title("Feature Importance (Random Forest)", fontsize=14)
plt.xlabel("Importance Score")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1006192167.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# # RECTANGULAR INI PAKE SEARCH_MODEL

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive
X = mydata.drop(['frekuensi', 'seizure'], axis=1)
y = mydata['seizure']

# %%
# split dataset train dan test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (2245632, 23)

# %%
X_test.shape
# Out:
# (561408, 23)

# %%
# ========================
# 2. Setup Stratified K-Fold
# ========================
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Inisialisasi model/buat model dasar
rf = RandomForestClassifier(random_state=42)

# Ruang hyperparameter untuk Grid Search
param_grid = {
    'n_estimators': [100],
    'max_depth': [20],
}

# Grid Search CV dengan cv=5/pencarian parameter
grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=skf,
    scoring='accuracy',
    n_jobs=-1
)

# Lakukan tuning/latih model/cross validation/pembentukan pohon
search_model = grid_search.fit(X_train, y_train)

# Dapatkan parameter terbaik
# print("Parameter terbaik:", grid_search.best_params_)
# print("Skor F1 terbaik:", grid_search.best_score_)

# %%
search_model.best_params_
# Out:
# {'max_depth': 20, 'n_estimators': 100}

# %%
search_model.best_score_
# Out:
# np.float64(0.8570682991196372)

# %%
# Prediksi data latih

y_train_pred = search_model.predict(X_train) #menghasilakn label prediksi dari fitur

print("📋 Classification Report - Data Latih:")
print(classification_report(y_train, y_train_pred, digits=4)) # mengevaluasi seberapa baik prediksi dibanding label asli


# ====================
# Confusion Matrix - Data Latih
# ====================

cm_train = confusion_matrix(y_train, y_train_pred)

# Visualisasi tanpa garis hitam
plt.figure(figsize=(5, 5))
sns.heatmap(cm_train, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Tidak Kejang', 'Kejang'],
            yticklabels=['Tidak Kejang', 'Kejang'],
            cbar=False)  # opsional: sembunyikan colorbar

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Data Latih")
plt.tight_layout()
plt.show()
# Out:
# 📋 Classification Report - Data Latih:
#               precision    recall  f1-score   support
#
#       kejang     0.9721    0.8005    0.8780   1122816
# tidak kejang     0.8305    0.9771    0.8978   1122816
#
#     accuracy                         0.8888   2245632
#    macro avg     0.9013    0.8888    0.8879   2245632
# weighted avg     0.9013    0.8888    0.8879   2245632

# %%
# ========================
# Tampilkan Semua Hasil Tuning
# ========================
# Ubah hasil cv_results_ jadi DataFrame
results_df = pd.DataFrame(grid_search.cv_results_) # cv_results_ atribut bawaan yang otomatis tersedia setelah kamu menjalankan fit()

# Ambil kolom penting dan urutkan berdasarkan skor tertinggi
display_cols = ['params', 'mean_test_score', 'rank_test_score']
sorted_results = results_df[display_cols].sort_values(by='mean_test_score', ascending=False) # nilai tertinggi ke terendah

# Tampilkan hasil
print("\n=== Semua Kombinasi dan Skornya (diurutkan dari terbaik) ===")
print(sorted_results.to_string(index=False))
# Out:
# === Semua Kombinasi dan Skornya (diurutkan dari terbaik) ===
#                                 params  mean_test_score  rank_test_score
# {'max_depth': 20, 'n_estimators': 100}         0.857068                1

# %%
# 5. Latih ulang model dengan data training penuh menggunakan parameter terbaik
#best_model = RandomForestClassifier(**best_params, random_state=42) #parameter dimasukkan secara dinamis dari dictionary.

# Latih ulang model terbaik di data training
#best_model.fit(X_train, y_train)

#best_model = grid_search.best_
#best_model = grid_search.best_estimator_

# %%
#pediksi data test
y_test_pred = search_model.predict(X_test)

# Akurasi data uji
print("\n📋 Classification Report - Data Uji:")
print(classification_report(y_test, y_test_pred, digits=4))

# ====================
# Confusion Matrix - Data Uji
# ====================

cm_test = confusion_matrix(y_test, y_test_pred)

# Visualisasi tanpa garis hitam
plt.figure(figsize=(5, 5))
sns.heatmap(cm_test, annot=True, fmt='d', cmap='Oranges',
            xticklabels=['Tidak Kejang', 'Kejang'],
            yticklabels=['Tidak Kejang', 'Kejang'],
            cbar=False)  # opsional: sembunyikan colorbar

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Data Uji")
plt.tight_layout()
plt.show()
# Out:
# 📋 Classification Report - Data Uji:
#               precision    recall  f1-score   support
#
#       kejang     0.9278    0.7748    0.8444    280704
# tidak kejang     0.8067    0.9397    0.8681    280704
#
#     accuracy                         0.8573    561408
#    macro avg     0.8673    0.8573    0.8563    561408
# weighted avg     0.8673    0.8573    0.8563    561408

# %% [markdown]
# # GRID RECTANGULAR FFT (skema baru) stratify

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive
X = mydata.drop(['frekuensi', 'seizure'], axis=1)
y = mydata['seizure']

# %%
# split dataset train dan test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (2245632, 23)

# %%
X_test.shape
# Out:
# (561408, 23)

# %%
# ========================
# 2. Setup Stratified K-Fold
# ========================
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Inisialisasi model/buat model dasar
rf = RandomForestClassifier(random_state=42)

# Ruang hyperparameter untuk Grid Search
param_grid = {
    'n_estimators': [100],
    'max_depth': [20],
}

# Grid Search CV dengan cv=5/pencarian parameter
grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=skf,
    scoring='accuracy',
    n_jobs=-1
)

# Lakukan tuning/latih model/cross validation/pembentukan pohon
grid_search.fit(X_train, y_train)

# Dapatkan parameter terbaik
print("Parameter terbaik:", grid_search.best_params_)
print("Skor F1 terbaik:", grid_search.best_score_)
# Out:
# Parameter terbaik: {'max_depth': 20, 'n_estimators': 100}
# Skor F1 terbaik: 0.8570682991196372

# %%
# ========================
# Tampilkan Semua Hasil Tuning
# ========================
# Ubah hasil cv_results_ jadi DataFrame
results_df = pd.DataFrame(grid_search.cv_results_) # cv_results_ atribut bawaan yang otomatis tersedia setelah kamu menjalankan fit()

# Ambil kolom penting dan urutkan berdasarkan skor tertinggi
display_cols = ['params', 'mean_test_score', 'rank_test_score']
sorted_results = results_df[display_cols].sort_values(by='mean_test_score', ascending=False) # nilai tertinggi ke terendah

# Tampilkan hasil
print("\n=== Semua Kombinasi dan Skornya (diurutkan dari terbaik) ===")
print(sorted_results.to_string(index=False))
# Out:
# === Semua Kombinasi dan Skornya (diurutkan dari terbaik) ===
#                                 params  mean_test_score  rank_test_score
# {'max_depth': 20, 'n_estimators': 100}         0.857068                1

# %%
# 5. Latih ulang model dengan data training penuh menggunakan parameter terbaik
#best_model = RandomForestClassifier(**best_params, random_state=42) #parameter dimasukkan secara dinamis dari dictionary.

# Latih ulang model terbaik di data training
#best_model.fit(X_train, y_train)

#best_model = grid_search.best_
best_model = grid_search.best_estimator_

# %%
# Prediksi data latih
from sklearn.metrics import classification_report
import seaborn as sns
import matplotlib.pyplot as plt
y_train_pred = best_model.predict(X_train) #menghasilakn label prediksi dari fitur

print("📋 Classification Report - Data Latih:")
print(classification_report(y_train, y_train_pred, digits=4)) # mengevaluasi seberapa baik prediksi dibanding label asli


# ====================
# Confusion Matrix - Data Latih
# ====================

cm_train = confusion_matrix(y_train, y_train_pred)

# Visualisasi tanpa garis hitam
plt.figure(figsize=(5, 5))
sns.heatmap(cm_train, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Tidak Kejang', 'Kejang'],
            yticklabels=['Tidak Kejang', 'Kejang'],
            cbar=False)  # opsional: sembunyikan colorbar

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Data Latih")
plt.tight_layout()
plt.show()
# Out:
# 📋 Classification Report - Data Latih:
#               precision    recall  f1-score   support
#
#       kejang     0.9721    0.8005    0.8780   1122816
# tidak kejang     0.8305    0.9771    0.8978   1122816
#
#     accuracy                         0.8888   2245632
#    macro avg     0.9013    0.8888    0.8879   2245632
# weighted avg     0.9013    0.8888    0.8879   2245632

# %%
#pediksi data test
y_test_pred = best_model.predict(X_test)

# Akurasi data uji
print("\n📋 Classification Report - Data Uji:")
print(classification_report(y_test, y_test_pred, digits=4))

# ====================
# Confusion Matrix - Data Uji
# ====================

cm_test = confusion_matrix(y_test, y_test_pred)

# Visualisasi tanpa garis hitam
plt.figure(figsize=(5, 5))
sns.heatmap(cm_test, annot=True, fmt='d', cmap='Oranges',
            xticklabels=['Tidak Kejang', 'Kejang'],
            yticklabels=['Tidak Kejang', 'Kejang'],
            cbar=False)  # opsional: sembunyikan colorbar

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Data Uji")
plt.tight_layout()
plt.show()
# Out:
# 📋 Classification Report - Data Uji:
#               precision    recall  f1-score   support
#
#       kejang     0.9278    0.7748    0.8444    280704
# tidak kejang     0.8067    0.9397    0.8681    280704
#
#     accuracy                         0.8573    561408
#    macro avg     0.8673    0.8573    0.8563    561408
# weighted avg     0.8673    0.8573    0.8563    561408
