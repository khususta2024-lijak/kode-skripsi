# %%
from google.colab import drive
drive.mount ('/content/drive')
# %cd /content/drive/MyDrive/TA
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/TA

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/TA/RECTANGULAR.csv')
df
# Out:
#            FP1-F7     F7-T7     T7-P7     P7-O1    FP1-F3     F3-C3     C3-P3  \
# 0        0.001195  0.001793  0.000520  0.002409  0.001823  0.000805  0.000324
# 1        0.000789  0.001850  0.000158  0.001468  0.001465  0.000763  0.000932
# 2        0.002511  0.002253  0.000593  0.001467  0.003102  0.001204  0.000956
# 3        0.003001  0.002348  0.001485  0.002485  0.004089  0.001443  0.000193
# 4        0.001659  0.000911  0.001210  0.002071  0.000594  0.001194  0.000688
# ...           ...       ...       ...       ...       ...       ...       ...
# 2807035  0.000061  0.000052  0.000018  0.000045  0.000042  0.000269  0.000277
# 2807036  0.000010  0.000024  0.000038  0.000010  0.000102  0.000322  0.000254
# 2807037  0.000061  0.000052  0.000018  0.000045  0.000042  0.000269  0.000277
# 2807038  0.000010  0.000024  0.000038  0.000010  0.000102  0.000322  0.000254
# 2807039  0.000061  0.000052  0.000018  0.000045  0.000042  0.000269  0.000277
#
# ...

# %%
df1 = pd.read_csv('/content/drive/MyDrive/TA/df2.csv')
df1
# Out:
#          FP1-F7     F7-T7     T7-P7     P7-O1    FP1-F3     F3-C3     C3-P3  \
# 0      0.000280  0.000103 -0.000068  0.000008  0.000285  0.000005 -0.000001
# 1      0.000250  0.000055  0.000047 -0.000017  0.000305  0.000014 -0.000002
# 2      0.000243  0.000088  0.000016 -0.000015  0.000307  0.000008  0.000004
# 3      0.000246  0.000116 -0.000027  0.000020  0.000284  0.000021  0.000024
# 4      0.000280  0.000126 -0.000054  0.000005  0.000262  0.000032  0.000040
# ...         ...       ...       ...       ...       ...       ...       ...
# 10236  0.000002  0.000081 -0.000031 -0.000029  0.000066 -0.000027 -0.000060
# 10237 -0.000010  0.000065 -0.000005 -0.000007  0.000064 -0.000037 -0.000053
# 10238 -0.000018  0.000059 -0.000005 -0.000011  0.000068 -0.000047 -0.000062
# 10239 -0.000020  0.000064 -0.000015 -0.000006  0.000069 -0.000049 -0.000065
# 10240 -0.000013  0.000063 -0.000043 -0.000009  0.000065 -0.000047 -0.000069
#
# ...

# %%
df1 = df1.drop(['seizure'], axis=1)
df1
# Out:
#          FP1-F7     F7-T7     T7-P7     P7-O1    FP1-F3     F3-C3     C3-P3  \
# 0      0.000280  0.000103 -0.000068  0.000008  0.000285  0.000005 -0.000001
# 1      0.000250  0.000055  0.000047 -0.000017  0.000305  0.000014 -0.000002
# 2      0.000243  0.000088  0.000016 -0.000015  0.000307  0.000008  0.000004
# 3      0.000246  0.000116 -0.000027  0.000020  0.000284  0.000021  0.000024
# 4      0.000280  0.000126 -0.000054  0.000005  0.000262  0.000032  0.000040
# ...         ...       ...       ...       ...       ...       ...       ...
# 10236  0.000002  0.000081 -0.000031 -0.000029  0.000066 -0.000027 -0.000060
# 10237 -0.000010  0.000065 -0.000005 -0.000007  0.000064 -0.000037 -0.000053
# 10238 -0.000018  0.000059 -0.000005 -0.000011  0.000068 -0.000047 -0.000062
# 10239 -0.000020  0.000064 -0.000015 -0.000006  0.000069 -0.000049 -0.000065
# 10240 -0.000013  0.000063 -0.000043 -0.000009  0.000065 -0.000047 -0.000069
#
# ...

# %%
from scipy.signal import firwin

f1 = 1
f2 = 50
fs = 256
nyquist = fs/2
numtaps = 20

normalisasi = [f1/nyquist, f2/nyquist]

taps = firwin(numtaps, normalisasi, window='hamming', pass_zero='bandpass')
taps
# Out:
# array([-2.73917693e-03, -4.14347389e-03,  2.71549984e-04,  1.18022194e-02,
#         7.80554219e-03, -3.27773241e-02, -6.60766939e-02,  1.33074315e-03,
#         1.86255719e-01,  3.57376545e-01,  3.57376545e-01,  1.86255719e-01,
#         1.33074315e-03, -6.60766939e-02, -3.27773241e-02,  7.80554219e-03,
#         1.18022194e-02,  2.71549984e-04, -4.14347389e-03, -2.73917693e-03])

# %%
from scipy.signal import lfilter

filtering = lfilter(taps, 1, df1)
filtering
# Out:
# array([[-7.67906011e-07, -1.44467099e-06, -1.65323704e-07, ...,
#          2.38973209e-06,  1.85202393e-05, -1.64324695e-01],
#        [-6.85496586e-07, -1.18837160e-06, -2.90088248e-07, ...,
#         -7.10832123e-06,  5.43827164e-06, -1.64341146e-01],
#        [-6.66232045e-07, -1.24913188e-06, -3.42368806e-07, ...,
#         -8.03510607e-06, -1.37721316e-05, -1.64386165e-01],
#        ...,
#        [ 4.86964788e-08, -8.84814625e-08, -2.36718772e-07, ...,
#          2.02963240e-05,  5.85875317e-05, -2.73833508e-01],
#        [ 5.51179924e-08, -9.16108514e-08, -2.30026342e-07, ...,
#          1.86324726e-05,  5.57977930e-05, -2.73847743e-01],
#        [ 3.47831991e-08, -1.21300454e-07, -1.48263084e-07, ...,
#          1.73067842e-05,  5.08861741e-05, -2.73865594e-01]])

# %%
import matplotlib.pyplot as plt

plt.plot(df['frekuensi'], df['C3-P3'])
plt.show()

# %%
# 5 x 3. string, 2 numerik

data = {
    'nama' : ['kejang', 'tidak kejang', 'epilepsi', 'tidak epilepsi'],
    'frekuensi' : [12, 13, 14, 15],
    'waktu' : [1, 2, 3, 4]
}

df = pd.DataFrame(data)
df
# Out:
#              nama  frekuensi  waktu
# 0          kejang         12      1
# 1    tidak kejang         13      2
# 2        epilepsi         14      3
# 3  tidak epilepsi         15      4

# %%
import matplotlib.pyplot as plt

plt.hist(df['nama'], df['waktu'])
plt.hist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4285845009.py in <cell line: 0>()
#       2
#       3 plt.hist(df['nama'], df['waktu'])
# ----> 4 plt.hist()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# TypeError: hist() missing 1 required positional argument: 'x'

# %%
plt.hist(df['nama'], df['waktu'])
plt.hist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1751443550.py in <cell line: 0>()
#       1 plt.hist(df['nama'], df['waktu'])
# ----> 2 plt.hist()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# TypeError: hist() missing 1 required positional argument: 'x'

# %%
plt.bar([df['nama'], df['waktu']]) & ([df['nama'], df['frekuensi']])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3062814736.py in <cell line: 0>()
# ----> 1 plt.bar([df['nama'], df['waktu']]) & ([df['nama'], df['frekuensi']])
#       2 plt.show()
#
# TypeError: bar() missing 1 required positional argument: 'height'
